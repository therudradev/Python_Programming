# %% [markdown]
# <a href="https://colab.research.google.com/github/therudradev/Python_Programming/blob/main/Interview_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# | **No.** | **Question**                                       | **Answer**                                                                                                                        |
# | ------- | -------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------- |
# | 1       | What is Python?                                    | Python is a high-level, interpreted, general-purpose programming language known for its simplicity and readability.               |
# | 2       | What are the benefits of using Python?             | Easy to learn, readable syntax, huge library support, cross-platform, open source, supports multiple paradigms, strong community. |
# | 3       | What is a dynamically typed language?              | A language where variable types are checked at runtime, not before execution. Python is dynamically typed.                        |
# | 4       | What is an Interpreted language?                   | A language executed line-by-line by an interpreter instead of being compiled into machine code beforehand.                        |
# | 5       | What is PEP 8 and why is it important?             | PEP 8 is the official Python style guide. It ensures code readability, consistency, and best practices.                           |
# | 6       | What are the common built-in data types in Python? | `int`, `float`, `complex`, `str`, `list`, `tuple`, `set`, `dict`, `bool`, `NoneType`.                                             |
# | 7       | Explain the ternary operator in Python.            | A one-line conditional expression: `x if condition else y`                                                                        |
# | 8       | What does the `is` operator do?                    | It checks whether two variables refer to the **same object in memory**.                                                           |
# | 9       | Disadvantages of Python                            | Slower speed, high memory usage, not ideal for mobile apps, weak for low-level programming.                                       |
# | 10      | How are strings stored in Python?                  | Strings are stored as **immutable objects** in memory using Unicode encoding.                                                     |
# | 11      | What is the Zen of Python?                         | A philosophy of Python’s design principles accessed by `import this`. It emphasizes readability and simplicity.                   |
# | 12      | Identity operator (`is`) vs `==`                   | `is` checks **memory identity**, `==` checks **value equality**.                                                                  |
# | 13      | What do variables represent in Python?             | Variables are **references to objects** in memory, not fixed memory locations.                                                    |
# | 14      | Modules vs Packages vs Libraries                   | **Module:** single `.py` file; **Package:** folder of modules; **Library:** collection of packages for a task.                    |
# | 15      | Why is `0.3 + 0.2 ≠ 0.1` in Python?                | Due to **floating-point precision errors** in binary representation.                                                              |
# | 16      | Python Docstrings                                  | Special strings (`""" """`) used to document modules, classes, functions. Accessible using `help()` or `__doc__`.                 |

# %% [markdown]
# `1.	What is Python?` <br>
# Python is a high-level, interpreted, general-purpose programming language. Being a general-purpose language, it can be used to build almost any type of application with the right tools/libraries. Additionally, python supports objects, modules, threads, exception- handling, and automatic memory management which help in modelling real-world problems and building applications to solve these problems. <br>
# Benefits of using Python: <br>
# * Python is a general-purpose programming language that has a simple, easy-to-learn syntax that emphasizes readability and
# therefore reduces the cost of program maintenance. Moreover, the language is capable of scripting, is completely open-
# source, and supports third-party packages encouraging modularity and code reuse.
# * Its high-level data structures, combined with dynamic typing and dynamic binding, attract a huge community of developers for
# Rapid Application Development and deployment.

# %% [markdown]
# `2.	What are the benefits of using Python?` <br>
# Before we understand a dynamically typed language, we should learn about what typing is. Typing refers to type-checking in programming languages. In a strongly-typed language, such as Python, "1" + 2 will result in a type error since these languages don't allow for "type-coercion" (implicit conversion of data types). On the other hand, a weakly-typed language, such as Javascript, will simply output "12" as result. <br>
# Type-checking can be done at two stages:<br>
# * Static - Data Types are checked before execution.
# * Dynamic - Data Types are checked during execution. Python is an interpreted language, executes each statement line by line and thus type-checking is done on the fly, during execution. Hence, Python is a Dynamically Typed Language.

# %% [markdown]
# `3.	What is a dynamically typed language?` <br>
